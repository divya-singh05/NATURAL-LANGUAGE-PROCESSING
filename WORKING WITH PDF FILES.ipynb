# %%
pip install PyPDF2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import PyPDF2

# %%
from IPython.display import IFrame

# %%
pdf_path=IFrame(r"C:\Users\DIVYA SINGH\OneDrive\Documents\GOVT..pdf", width=600, height=400)
pdf_path
# Out:
#         <iframe
#             width="600"
#             height="400"
#             src="C:\Users\DIVYA SINGH\OneDrive\Documents\GOVT..pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
file_path=r"C:\Users\DIVYA SINGH\OneDrive\Documents\GOVT..pdf"
with open(file_path, 'rb') as f:
    pdf_data=f.read()

print(type(pdf_data))
# Out:
# <class 'bytes'>

# %%
from PyPDF2 import PdfReader

# %%
pdf_reader=PyPDF2.PdfReader(file_path)

# %%
page_one=pdf_reader.pages[0]

# %%
len(pdf_reader.pages)
# Out:
# 3

# %%
page_one_text=page_one.extract_text()

# %%
page_one_text
# Out:
# "GOVT.OF NCT OF DELHI  \nNEHRU HOMOEOPATHIC MEDICAL COLLEGE AND HOSPITAL  \n DEFENCE COLONY  NEW DELHI -110024  \n \nEvent Report: Seminar and Speech on Bhagwan Birsa Munda at NHMC  \n \nOn the occasion of celebrating the legacy of Bhagwan Birsa Munda, NHMC organized a \ncommemorative event that highlighted the extraordinary contributions of this revered tribal leader \nand freedom fighter. The event aimed to educate and inspire students about his life, values, and his \nsignificant role in India's history, particu larly in tribal empowerment and the freedom struggle.  \n \nSeminar Conducted  \n \nThe centerpiece of the event was an insightful seminar hosted in the college auditorium. Esteemed \nspeakers, including professors and guest lecturers, shared detailed accounts of Birsa Munda's life. \nThe seminar delved into his early life struggles, leadersh ip in the Ulgulan (The Great Rebellion), and \nhis unwavering commitment to tribal rights. The lectures were accompanied by multimed
# ...

# %%
f.close()

# %%
with open(file_path,'rb') as f:
    pdf_data=f.read()

# %%
pdf_reader=PyPDF2.PdfReader(file_path)

# %%
first_page=pdf_reader.pages[0]

# %%
pdf_writer=PyPDF2.PdfWriter(f)

# %%
pdf_writer.add_page(first_page)
# Out:
# {'/Type': '/Page',
#  '/Resources': {'/Font': {'/F1': {'/Type': '/Font',
#     '/Subtype': '/Type0',
#     '/BaseFont': '/BCDEEE+Calibri-Bold',
#     '/Encoding': '/Identity-H',
#     '/DescendantFonts': [IndirectObject(7, 0, 2772188517376)],
#     '/ToUnicode': {'/Filter': '/FlateDecode'}},
#    '/F2': {'/Type': '/Font',
#     '/Subtype': '/TrueType',
#     '/Name': '/F2',
#     '/BaseFont': '/BCDFEE+Calibri-Bold',
#     '/Encoding': '/WinAnsiEncoding',
#     '/FontDescriptor': {'/Type': '/FontDescriptor',
#      '/FontName': '/BCDFEE+Calibri-Bold',
#      '/Flags': 32,
#      '/ItalicAngle': 0,
#      '/Ascent': 750,
#      '/Descent': -250,
#      '/CapHeight': 750,
#      '/AvgWidth': 536,
#      '/MaxWidth': 1781,
#      '/FontWeight': 700,
#      '/XHeight': 250,
#      '/StemV': 53,
#      '/FontBBox': [-519, -250, 1263, 750],
#      '/FontFile2': {'/Filter': '/FlateDecode', '/Length1': 116556}},
#     '/FirstChar': 32,
#     '/LastChar': 32,
#     '/Widths': [226]},
# ...

# %%
pdf_output=open('New_pdf.pdf','wb')

# %%
pdf_writer.write(pdf_output)
# Out:
# (False, <_io.BufferedWriter name='New_pdf.pdf'>)

# %%
pdf_output.close()
f.close()

# %%
f=open('New_pdf.pdf','rb')

# %%
pdf_reader=PyPDF2.PdfReader(f)

# %%
page_one=pdf_reader.pages[0]

# %%
len(pdf_reader.pages)
# Out:
# 1

# %%
page_one_text=page_one.extract_text()

# %%
page_one_text
# Out:
# "GOVT.OF NCT OF DELHI  \nNEHRU HOMOEOPATHIC MEDICAL COLLEGE AND HOSPITAL  \n DEFENCE COLONY  NEW DELHI -110024  \n \nEvent Report: Seminar and Speech on Bhagwan Birsa Munda at NHMC  \n \nOn the occasion of celebrating the legacy of Bhagwan Birsa Munda, NHMC organized a \ncommemorative event that highlighted the extraordinary contributions of this revered tribal leader \nand freedom fighter. The event aimed to educate and inspire students about his life, values, and his \nsignificant role in India's history, particu larly in tribal empowerment and the freedom struggle.  \n \nSeminar Conducted  \n \nThe centerpiece of the event was an insightful seminar hosted in the college auditorium. Esteemed \nspeakers, including professors and guest lecturers, shared detailed accounts of Birsa Munda's life. \nThe seminar delved into his early life struggles, leadersh ip in the Ulgulan (The Great Rebellion), and \nhis unwavering commitment to tribal rights. The lectures were accompanied by multimed
# ...

# %%
## Using Loops

# %%
with open(file_path,'rb') as f:
    pdf_data=f.read()

# %%
f=r"C:\Users\DIVYA SINGH\OneDrive\Documents\GOVT..pdf"
pdf_text=[]
pdf_reader=PyPDF2.PdfReader(f)
for p in range(len(pdf_reader.pages)):
    pages=pdf_reader.pages[p]
    pdf_text.append(pages.extract_text())

# %%
pdf_text
# Out:
# ["GOVT.OF NCT OF DELHI  \nNEHRU HOMOEOPATHIC MEDICAL COLLEGE AND HOSPITAL  \n DEFENCE COLONY  NEW DELHI -110024  \n \nEvent Report: Seminar and Speech on Bhagwan Birsa Munda at NHMC  \n \nOn the occasion of celebrating the legacy of Bhagwan Birsa Munda, NHMC organized a \ncommemorative event that highlighted the extraordinary contributions of this revered tribal leader \nand freedom fighter. The event aimed to educate and inspire students about his life, values, and his \nsignificant role in India's history, particu larly in tribal empowerment and the freedom struggle.  \n \nSeminar Conducted  \n \nThe centerpiece of the event was an insightful seminar hosted in the college auditorium. Esteemed \nspeakers, including professors and guest lecturers, shared detailed accounts of Birsa Munda's life. \nThe seminar delved into his early life struggles, leadersh ip in the Ulgulan (The Great Rebellion), and \nhis unwavering commitment to tribal rights. The lectures were accompanied by multime
# ...

# %%
for page in pdf_text:
    print(page)
    print("\n")
    print("\n")
    print("\n")
# Out:
# GOVT.OF NCT OF DELHI
# NEHRU HOMOEOPATHIC MEDICAL COLLEGE AND HOSPITAL
#  DEFENCE COLONY  NEW DELHI -110024
#
# Event Report: Seminar and Speech on Bhagwan Birsa Munda at NHMC
#
# On the occasion of celebrating the legacy of Bhagwan Birsa Munda, NHMC organized a
# commemorative event that highlighted the extraordinary contributions of this revered tribal leader
# and freedom fighter. The event aimed to educate and inspire students about his life, values, and his
# significant role in India's history, particu larly in tribal empowerment and the freedom struggle.
#
# Seminar Conducted
#
# The centerpiece of the event was an insightful seminar hosted in the college auditorium. Esteemed
# speakers, including professors and guest lecturers, shared detailed accounts of Birsa Munda's life.
# The seminar delved into his early life struggles, leadersh ip in the Ulgulan (The Great Rebellion), and
# his unwavering commitment to tribal rights. The lectures were accompanied by multimedia
# ...
