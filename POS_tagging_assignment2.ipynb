# %% [markdown]
# **Implement POS tagging on a text corpus using an NLP library (like NLTK or SpaCy). Analyze the grammatical structure of sentences using syntactic/dependency parsing.**

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
text="""
Python is a high-level, general-purpose programming language. Its design philosophy emphasizes code readability with the use of significant indentation.[34] Python is dynamically type-checked and garbage-collected. It supports multiple programming paradigms, including structured (particularly procedural), object-oriented and functional programming.

Guido van Rossum began working on Python in the late 1980s as a successor to the ABC programming language. Python 3.0, released in 2008, was a major revision and not completely backward-compatible with earlier versions. Beginning with Python 3.5,[35] capabilities and keywords for typing were added to the language, allowing optional static typing.[36] As of 2025, the Python Software Foundation supports Python 3.10, 3.11, 3.12, 3.13, and 3.14, following the projects annual release cycle and five-year support policy. Earlier versions in the 3.x series have reached end-of-life and no longer receive security updates."""

# %%
doc=nlp(text)

# %% [markdown]
# POS tagging

# %%
for token in doc:
    print(f"{token.text:15}  POS: {token.pos_:10}  TAG: {token.tag_:10}  DEP: {token.dep_}  Description: {spacy.explain(token.tag_)}")
# Out:
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Python           POS: PROPN       TAG: NNP         DEP: nsubj  Description: noun, proper singular
# is               POS: AUX         TAG: VBZ         DEP: ROOT  Description: verb, 3rd person singular present
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# high             POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# -                POS: PUNCT       TAG: HYPH        DEP: punct  Description: punctuation mark, hyphen
# level            POS: NOUN        TAG: NN          DEP: nmod  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# general          POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# -                POS: PUNCT       TAG: HYPH        DEP: punct  Description: punctuation mark, hyphen
# purpose          POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# programming      POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# language         POS: NOUN        TAG: NN          DEP: attr  Description: noun, singular or mass
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# Its              POS: PRON        TAG: PRP$        DEP: poss  Description: pronoun, possessive
# design           POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# philosophy       POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# emphasizes       POS: VERB        TAG: VBZ         DEP: ROOT  Description: verb, 3rd person singular present
# code             POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# readability      POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# with             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# use              POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# significant      POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# indentation.[34  POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# ]                POS: X           TAG: XX          DEP: punct  Description: unknown
# Python           POS: PROPN       TAG: NNP         DEP: nsubj  Description: noun, proper singular
# is               POS: AUX         TAG: VBZ         DEP: ROOT  Description: verb, 3rd person singular present
# dynamically      POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# type             POS: NOUN        TAG: NN          DEP: npadvmod  Description: noun, singular or mass
# -                POS: PUNCT       TAG: HYPH        DEP: punct  Description: punctuation mark, hyphen
# checked          POS: VERB        TAG: VBN         DEP: acomp  Description: verb, past participle
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# garbage          POS: NOUN        TAG: NN          DEP: npadvmod  Description: noun, singular or mass
# -                POS: PUNCT       TAG: HYPH        DEP: punct  Description: punctuation mark, hyphen
# collected        POS: VERB        TAG: VBN         DEP: conj  Description: verb, past participle
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# It               POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# supports         POS: VERB        TAG: VBZ         DEP: ROOT  Description: verb, 3rd person singular present
# multiple         POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# programming      POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# paradigms        POS: NOUN        TAG: NNS         DEP: dobj  Description: noun, plural
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# including        POS: VERB        TAG: VBG         DEP: prep  Description: verb, gerund or present participle
# structured       POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# (                POS: PUNCT       TAG: -LRB-       DEP: punct  Description: left round bracket
# particularly     POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# procedural       POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# )                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# object           POS: NOUN        TAG: NN          DEP: npadvmod  Description: noun, singular or mass
# -                POS: PUNCT       TAG: HYPH        DEP: punct  Description: punctuation mark, hyphen
# oriented         POS: VERB        TAG: VBN         DEP: amod  Description: verb, past participle
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# functional       POS: ADJ         TAG: JJ          DEP: conj  Description: adjective (English), other noun-modifier (Chinese)
# programming      POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
#
#
#                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Guido            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# van              POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Rossum           POS: PROPN       TAG: NNP         DEP: nsubj  Description: noun, proper singular
# began            POS: VERB        TAG: VBD         DEP: ROOT  Description: verb, past tense
# working          POS: VERB        TAG: VBG         DEP: xcomp  Description: verb, gerund or present participle
# on               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# Python           POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# late             POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# 1980s            POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# as               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# successor        POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# to               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# ABC              POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# programming      POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# language         POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# Python           POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# 3.0              POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# released         POS: VERB        TAG: VBN         DEP: acl  Description: verb, past participle
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 2008             POS: NUM         TAG: CD          DEP: pobj  Description: cardinal number
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# was              POS: AUX         TAG: VBD         DEP: ROOT  Description: verb, past tense
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# major            POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# revision         POS: NOUN        TAG: NN          DEP: attr  Description: noun, singular or mass
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# not              POS: PART        TAG: RB          DEP: neg  Description: adverb
# completely       POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# backward         POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# -                POS: PUNCT       TAG: HYPH        DEP: punct  Description: punctuation mark, hyphen
# compatible       POS: ADJ         TAG: JJ          DEP: conj  Description: adjective (English), other noun-modifier (Chinese)
# with             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# earlier          POS: ADJ         TAG: JJR         DEP: amod  Description: adjective, comparative
# versions         POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# Beginning        POS: VERB        TAG: VBG         DEP: csubjpass  Description: verb, gerund or present participle
# with             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# Python           POS: PROPN       TAG: NNP         DEP: nmod  Description: noun, proper singular
# 3.5,[35          POS: PROPN       TAG: NNP         DEP: nmod  Description: noun, proper singular
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# capabilities     POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# keywords         POS: NOUN        TAG: NNS         DEP: conj  Description: noun, plural
# for              POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# typing           POS: VERB        TAG: VBG         DEP: pobj  Description: verb, gerund or present participle
# were             POS: AUX         TAG: VBD         DEP: auxpass  Description: verb, past tense
# added            POS: VERB        TAG: VBN         DEP: ROOT  Description: verb, past participle
# to               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# language         POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# allowing         POS: VERB        TAG: VBG         DEP: advcl  Description: verb, gerund or present participle
# optional         POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# static           POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# typing.[36       POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# ]                POS: X           TAG: XX          DEP: punct  Description: unknown
# As               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 2025             POS: NUM         TAG: CD          DEP: pobj  Description: cardinal number
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# Python           POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Software         POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Foundation       POS: PROPN       TAG: NNP         DEP: nsubj  Description: noun, proper singular
# supports         POS: VERB        TAG: VBZ         DEP: ccomp  Description: verb, 3rd person singular present
# Python           POS: PROPN       TAG: NNP         DEP: dobj  Description: noun, proper singular
# 3.10             POS: NUM         TAG: CD          DEP: npadvmod  Description: cardinal number
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# 3.11             POS: NUM         TAG: CD          DEP: appos  Description: cardinal number
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# 3.12             POS: NUM         TAG: CD          DEP: dobj  Description: cardinal number
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# 3.13             POS: NUM         TAG: CD          DEP: appos  Description: cardinal number
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# 3.14             POS: NUM         TAG: CD          DEP: conj  Description: cardinal number
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# following        POS: VERB        TAG: VBG         DEP: prep  Description: verb, gerund or present participle
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# projects         POS: NOUN        TAG: NNS         DEP: nmod  Description: noun, plural
# annual           POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# release          POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# cycle            POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# five             POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# -                POS: PUNCT       TAG: HYPH        DEP: punct  Description: punctuation mark, hyphen
# year             POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# support          POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# policy           POS: NOUN        TAG: NN          DEP: conj  Description: noun, singular or mass
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# Earlier          POS: ADJ         TAG: JJR         DEP: amod  Description: adjective, comparative
# versions         POS: NOUN        TAG: NNS         DEP: nsubj  Description: noun, plural
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# 3.x              POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# series           POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# have             POS: AUX         TAG: VBP         DEP: aux  Description: verb, non-3rd person singular present
# reached          POS: VERB        TAG: VBN         DEP: ROOT  Description: verb, past participle
# end              POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# -                POS: PUNCT       TAG: HYPH        DEP: punct  Description: punctuation mark, hyphen
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# -                POS: PUNCT       TAG: HYPH        DEP: punct  Description: punctuation mark, hyphen
# life             POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# no               POS: ADV         TAG: RB          DEP: neg  Description: adverb
# longer           POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# receive          POS: VERB        TAG: VB          DEP: conj  Description: verb, base form
# security         POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# updates          POS: NOUN        TAG: NNS         DEP: dobj  Description: noun, plural
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer

# %% [markdown]
# Dependency Parsing

# %%
for token in doc:
    print(f"{token.text:12} <--{token.dep_:10}-- {token.head.text}")
# Out:
#             <--dep       -- Python
# Python       <--nsubj     -- is
# is           <--ROOT      -- is
# a            <--det       -- language
# high         <--amod      -- level
# -            <--punct     -- level
# level        <--nmod      -- language
# ,            <--punct     -- language
# general      <--amod      -- purpose
# -            <--punct     -- purpose
# purpose      <--compound  -- language
# programming  <--compound  -- language
# language     <--attr      -- is
# .            <--punct     -- is
# Its          <--poss      -- philosophy
# design       <--compound  -- philosophy
# philosophy   <--nsubj     -- emphasizes
# emphasizes   <--ROOT      -- emphasizes
# code         <--compound  -- readability
# readability  <--dobj      -- emphasizes
# with         <--prep      -- readability
# the          <--det       -- use
# use          <--pobj      -- with
# of           <--prep      -- use
# significant  <--amod      -- indentation.[34
# indentation.[34 <--pobj      -- of
# ]            <--punct     -- emphasizes
# Python       <--nsubj     -- is
# is           <--ROOT      -- is
# dynamically  <--advmod    -- checked
# type         <--npadvmod  -- checked
# -            <--punct     -- checked
# checked      <--acomp     -- is
# and          <--cc        -- checked
# garbage      <--npadvmod  -- collected
# -            <--punct     -- collected
# collected    <--conj      -- checked
# .            <--punct     -- is
# It           <--nsubj     -- supports
# supports     <--ROOT      -- supports
# multiple     <--amod      -- paradigms
# programming  <--compound  -- paradigms
# paradigms    <--dobj      -- supports
# ,            <--punct     -- paradigms
# including    <--prep      -- paradigms
# structured   <--amod      -- programming
# (            <--punct     -- structured
# particularly <--advmod    -- procedural
# procedural   <--amod      -- structured
# )            <--punct     -- structured
# ,            <--punct     -- structured
# object       <--npadvmod  -- oriented
# -            <--punct     -- oriented
# oriented     <--amod      -- programming
# and          <--cc        -- oriented
# functional   <--conj      -- oriented
# programming  <--pobj      -- including
# .            <--punct     -- supports
#
#
#            <--dep       -- .
# Guido        <--compound  -- van
# van          <--compound  -- Rossum
# Rossum       <--nsubj     -- began
# began        <--ROOT      -- began
# working      <--xcomp     -- began
# on           <--prep      -- working
# Python       <--pobj      -- on
# in           <--prep      -- working
# the          <--det       -- 1980s
# late         <--amod      -- 1980s
# 1980s        <--pobj      -- in
# as           <--prep      -- working
# a            <--det       -- successor
# successor    <--pobj      -- as
# to           <--prep      -- successor
# the          <--det       -- language
# ABC          <--compound  -- programming
# programming  <--compound  -- language
# language     <--pobj      -- to
# .            <--punct     -- began
# Python       <--nsubj     -- was
# 3.0          <--nummod    -- Python
# ,            <--punct     -- Python
# released     <--acl       -- Python
# in           <--prep      -- released
# 2008         <--pobj      -- in
# ,            <--punct     -- Python
# was          <--ROOT      -- was
# a            <--det       -- revision
# major        <--amod      -- revision
# revision     <--attr      -- was
# and          <--cc        -- revision
# not          <--neg       -- compatible
# completely   <--advmod    -- compatible
# backward     <--advmod    -- compatible
# -            <--punct     -- compatible
# compatible   <--conj      -- revision
# with         <--prep      -- compatible
# earlier      <--amod      -- versions
# versions     <--pobj      -- with
# .            <--punct     -- was
# Beginning    <--csubjpass -- added
# with         <--prep      -- Beginning
# Python       <--nmod      -- capabilities
# 3.5,[35      <--nmod      -- capabilities
# ]            <--punct     -- 3.5,[35
# capabilities <--pobj      -- with
# and          <--cc        -- capabilities
# keywords     <--conj      -- capabilities
# for          <--prep      -- keywords
# typing       <--pobj      -- for
# were         <--auxpass   -- added
# added        <--ROOT      -- added
# to           <--prep      -- added
# the          <--det       -- language
# language     <--pobj      -- to
# ,            <--punct     -- added
# allowing     <--advcl     -- added
# optional     <--amod      -- typing.[36
# static       <--amod      -- typing.[36
# typing.[36   <--dobj      -- allowing
# ]            <--punct     -- allowing
# As           <--prep      -- supports
# of           <--prep      -- As
# 2025         <--pobj      -- of
# ,            <--punct     -- supports
# the          <--det       -- Foundation
# Python       <--compound  -- Foundation
# Software     <--compound  -- Foundation
# Foundation   <--nsubj     -- supports
# supports     <--ccomp     -- allowing
# Python       <--dobj      -- supports
# 3.10         <--npadvmod  -- supports
# ,            <--punct     -- 3.10
# 3.11         <--appos     -- 3.10
# ,            <--punct     -- 3.10
# 3.12         <--dobj      -- supports
# ,            <--punct     -- 3.12
# 3.13         <--appos     -- 3.12
# ,            <--punct     -- 3.12
# and          <--cc        -- 3.12
# 3.14         <--conj      -- 3.12
# ,            <--punct     -- supports
# following    <--prep      -- supports
# the          <--det       -- projects
# projects     <--nmod      -- cycle
# annual       <--amod      -- cycle
# release      <--compound  -- cycle
# cycle        <--pobj      -- following
# and          <--cc        -- cycle
# five         <--nummod    -- year
# -            <--punct     -- year
# year         <--compound  -- policy
# support      <--compound  -- policy
# policy       <--conj      -- cycle
# .            <--punct     -- added
# Earlier      <--amod      -- versions
# versions     <--nsubj     -- reached
# in           <--prep      -- versions
# the          <--det       -- series
# 3.x          <--nummod    -- series
# series       <--pobj      -- in
# have         <--aux       -- reached
# reached      <--ROOT      -- reached
# end          <--dobj      -- reached
# -            <--punct     -- end
# of           <--prep      -- end
# -            <--punct     -- of
# life         <--pobj      -- of
# and          <--cc        -- reached
# no           <--neg       -- longer
# longer       <--advmod    -- receive
# receive      <--conj      -- reached
# security     <--compound  -- updates
# updates      <--dobj      -- receive
# .            <--punct     -- reached

# %% [markdown]
# Sentence wise grammar parsing

# %%
for sent in doc.sents:
    print("Sentence:", sent.text)
    for token in sent:
        print(f"  {token.text:15} {token.pos_:10} {token.dep_:10} --> {token.head.text}")
    print()
# Out:
# Sentence:
# Python is a high-level, general-purpose programming language.
#
#                SPACE      dep        --> Python
#   Python          PROPN      nsubj      --> is
#   is              AUX        ROOT       --> is
#   a               DET        det        --> language
#   high            ADJ        amod       --> level
#   -               PUNCT      punct      --> level
#   level           NOUN       nmod       --> language
#   ,               PUNCT      punct      --> language
#   general         ADJ        amod       --> purpose
#   -               PUNCT      punct      --> purpose
#   purpose         NOUN       compound   --> language
#   programming     NOUN       compound   --> language
#   language        NOUN       attr       --> is
#   .               PUNCT      punct      --> is
#
# Sentence: Its design philosophy emphasizes code readability with the use of significant indentation.[34]
#   Its             PRON       poss       --> philosophy
#   design          NOUN       compound   --> philosophy
#   philosophy      NOUN       nsubj      --> emphasizes
#   emphasizes      VERB       ROOT       --> emphasizes
#   code            NOUN       compound   --> readability
#   readability     NOUN       dobj       --> emphasizes
#   with            ADP        prep       --> readability
#   the             DET        det        --> use
#   use             NOUN       pobj       --> with
#   of              ADP        prep       --> use
#   significant     ADJ        amod       --> indentation.[34
#   indentation.[34 NOUN       pobj       --> of
#   ]               X          punct      --> emphasizes
#
# Sentence: Python is dynamically type-checked and garbage-collected.
#   Python          PROPN      nsubj      --> is
#   is              AUX        ROOT       --> is
#   dynamically     ADV        advmod     --> checked
#   type            NOUN       npadvmod   --> checked
#   -               PUNCT      punct      --> checked
#   checked         VERB       acomp      --> is
#   and             CCONJ      cc         --> checked
#   garbage         NOUN       npadvmod   --> collected
#   -               PUNCT      punct      --> collected
#   collected       VERB       conj       --> checked
#   .               PUNCT      punct      --> is
#
# Sentence: It supports multiple programming paradigms, including structured (particularly procedural), object-oriented and functional programming.
#
#
#   It              PRON       nsubj      --> supports
#   supports        VERB       ROOT       --> supports
#   multiple        ADJ        amod       --> paradigms
#   programming     NOUN       compound   --> paradigms
#   paradigms       NOUN       dobj       --> supports
#   ,               PUNCT      punct      --> paradigms
#   including       VERB       prep       --> paradigms
#   structured      ADJ        amod       --> programming
#   (               PUNCT      punct      --> structured
#   particularly    ADV        advmod     --> procedural
#   procedural      ADJ        amod       --> structured
#   )               PUNCT      punct      --> structured
#   ,               PUNCT      punct      --> structured
#   object          NOUN       npadvmod   --> oriented
#   -               PUNCT      punct      --> oriented
#   oriented        VERB       amod       --> programming
#   and             CCONJ      cc         --> oriented
#   functional      ADJ        conj       --> oriented
#   programming     NOUN       pobj       --> including
#   .               PUNCT      punct      --> supports
#
#
#               SPACE      dep        --> .
#
# Sentence: Guido van Rossum began working on Python in the late 1980s as a successor to the ABC programming language.
#   Guido           PROPN      compound   --> van
#   van             PROPN      compound   --> Rossum
#   Rossum          PROPN      nsubj      --> began
#   began           VERB       ROOT       --> began
#   working         VERB       xcomp      --> began
#   on              ADP        prep       --> working
#   Python          PROPN      pobj       --> on
#   in              ADP        prep       --> working
#   the             DET        det        --> 1980s
#   late            ADJ        amod       --> 1980s
#   1980s           NOUN       pobj       --> in
#   as              ADP        prep       --> working
#   a               DET        det        --> successor
#   successor       NOUN       pobj       --> as
#   to              ADP        prep       --> successor
#   the             DET        det        --> language
#   ABC             PROPN      compound   --> programming
#   programming     NOUN       compound   --> language
#   language        NOUN       pobj       --> to
#   .               PUNCT      punct      --> began
#
# Sentence: Python 3.0, released in 2008, was a major revision and not completely backward-compatible with earlier versions.
#   Python          NOUN       nsubj      --> was
#   3.0             NUM        nummod     --> Python
#   ,               PUNCT      punct      --> Python
#   released        VERB       acl        --> Python
#   in              ADP        prep       --> released
#   2008            NUM        pobj       --> in
#   ,               PUNCT      punct      --> Python
#   was             AUX        ROOT       --> was
#   a               DET        det        --> revision
#   major           ADJ        amod       --> revision
#   revision        NOUN       attr       --> was
#   and             CCONJ      cc         --> revision
#   not             PART       neg        --> compatible
#   completely      ADV        advmod     --> compatible
#   backward        ADV        advmod     --> compatible
#   -               PUNCT      punct      --> compatible
#   compatible      ADJ        conj       --> revision
#   with            ADP        prep       --> compatible
#   earlier         ADJ        amod       --> versions
#   versions        NOUN       pobj       --> with
#   .               PUNCT      punct      --> was
#
# Sentence: Beginning with Python 3.5,[35] capabilities and keywords for typing were added to the language, allowing optional static typing.[36] As of 2025, the Python Software Foundation supports Python 3.10, 3.11, 3.12, 3.13, and 3.14, following the projects annual release cycle and five-year support policy.
#   Beginning       VERB       csubjpass  --> added
#   with            ADP        prep       --> Beginning
#   Python          PROPN      nmod       --> capabilities
#   3.5,[35         PROPN      nmod       --> capabilities
#   ]               PUNCT      punct      --> 3.5,[35
#   capabilities    NOUN       pobj       --> with
#   and             CCONJ      cc         --> capabilities
#   keywords        NOUN       conj       --> capabilities
#   for             ADP        prep       --> keywords
#   typing          VERB       pobj       --> for
#   were            AUX        auxpass    --> added
#   added           VERB       ROOT       --> added
#   to              ADP        prep       --> added
#   the             DET        det        --> language
#   language        NOUN       pobj       --> to
#   ,               PUNCT      punct      --> added
#   allowing        VERB       advcl      --> added
#   optional        ADJ        amod       --> typing.[36
#   static          ADJ        amod       --> typing.[36
#   typing.[36      NOUN       dobj       --> allowing
#   ]               X          punct      --> allowing
#   As              ADP        prep       --> supports
#   of              ADP        prep       --> As
#   2025            NUM        pobj       --> of
#   ,               PUNCT      punct      --> supports
#   the             DET        det        --> Foundation
#   Python          PROPN      compound   --> Foundation
#   Software        PROPN      compound   --> Foundation
#   Foundation      PROPN      nsubj      --> supports
#   supports        VERB       ccomp      --> allowing
#   Python          PROPN      dobj       --> supports
#   3.10            NUM        npadvmod   --> supports
#   ,               PUNCT      punct      --> 3.10
#   3.11            NUM        appos      --> 3.10
#   ,               PUNCT      punct      --> 3.10
#   3.12            NUM        dobj       --> supports
#   ,               PUNCT      punct      --> 3.12
#   3.13            NUM        appos      --> 3.12
#   ,               PUNCT      punct      --> 3.12
#   and             CCONJ      cc         --> 3.12
#   3.14            NUM        conj       --> 3.12
#   ,               PUNCT      punct      --> supports
#   following       VERB       prep       --> supports
#   the             DET        det        --> projects
#   projects        NOUN       nmod       --> cycle
#   annual          ADJ        amod       --> cycle
#   release         NOUN       compound   --> cycle
#   cycle           NOUN       pobj       --> following
#   and             CCONJ      cc         --> cycle
#   five            NUM        nummod     --> year
#   -               PUNCT      punct      --> year
#   year            NOUN       compound   --> policy
#   support         NOUN       compound   --> policy
#   policy          NOUN       conj       --> cycle
#   .               PUNCT      punct      --> added
#
# Sentence: Earlier versions in the 3.x series have reached end-of-life and no longer receive security updates.
#   Earlier         ADJ        amod       --> versions
#   versions        NOUN       nsubj      --> reached
#   in              ADP        prep       --> versions
#   the             DET        det        --> series
#   3.x             NUM        nummod     --> series
#   series          NOUN       pobj       --> in
#   have            AUX        aux        --> reached
#   reached         VERB       ROOT       --> reached
#   end             NOUN       dobj       --> reached
#   -               PUNCT      punct      --> end
#   of              ADP        prep       --> end
#   -               PUNCT      punct      --> of
#   life            NOUN       pobj       --> of
#   and             CCONJ      cc         --> reached
#   no              ADV        neg        --> longer
#   longer          ADV        advmod     --> receive
#   receive         VERB       conj       --> reached
#   security        NOUN       compound   --> updates
#   updates         NOUN       dobj       --> receive
#   .               PUNCT      punct      --> reached

# %% [markdown]
# Visualization

# %%
from spacy import displacy

# %%
displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e81993e5a25e435880c6a72e5058845b-0" class="displacy" width="24900" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Python</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">high-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">level,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">general-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">purpose</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">programming</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">language.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">Its</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">design</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">philosophy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">emphasizes</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">code</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">readability</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">use</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">significant</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">indentation.[34]</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">Python</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">dynamically</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">type-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">checked</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">garbage-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">collected.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">It</tspan>
#     <tspan c

# %%
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"><br>Python is a high-level, general-purpose programming language. Its design philosophy emphasizes code readability with the use of significant indentation.[34] Python is dynamically type-checked and garbage-collected. It supports multiple programming paradigms, including structured (particularly procedural), object-oriented and functional programming.<br><br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Guido van Rossum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  began working on Python in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the late 1980s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  as a successor to the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ABC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  programming language. Python
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3.0
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# , released in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2008
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , was a major revision and not completely backward-compatible with earlier versions. Beginning with Python 3.5,[35] capabilities and keywords for typing were added to the language, allowing optional static typing.[36] As of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2025
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Python Software Foundation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  supports Python
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3.10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3.11
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3.12
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3.13
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# , and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3.14
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# , following the projects
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     annual
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  release cycle and
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     five-year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  support policy. Earlier versions in the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3.x
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  series have reached end-of-life and no longer receive security updates.</div></span>
